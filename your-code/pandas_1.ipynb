# %% [markdown]
# # Introduction to Pandas Lab
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# ### 1. Import Numpy and Pandas and alias them to `np` and `pd` respectively.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
series = pd.Series(lst)

# %% [markdown]
# ### 3. Use indexing to return the third value in the Series above.
#
# *Hint: Remember that indexing begins at 0.*

# %%
# Access the third value using standard indexing
third_value = series[2]

# Print the result
print(third_value)
# Out:
# 74.4

# %% [markdown]
# ### 4. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# Create the DataFrame
df = pd.DataFrame(b)

# Print the resulting DataFrame
print(df)
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 5. Rename the data frame columns based on the names in the list below.
#
# ```py
# list_names = ["Score_1", "Score_2", "Score_3", "Score_4", "Score_5"]
# ```

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
list_names = ["Score_1", "Score_2", "Score_3", "Score_4", "Score_5"]
# Method 1: Pass the names directly during creation
df = pd.DataFrame(b, columns=list_names)

# OR Method 2: Assign them to an existing DataFrame
# df.columns = list_names

# Print the resulting labeled DataFrame
print(df)
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 6. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
# Create the subset by passing a list of the desired column names
df_subset = df[["Score_1", "Score_3", "Score_5"]]

# Print the resulting subset DataFrame
print(df_subset)
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# ### 7. From the original data frame, calculate the average Score_3 value.

# %%
# Calculate the mean of the Score_3 column
score_3_average = df["Score_3"].mean()

# Print the result
print("Average Score_3:", score_3_average)
# Out:
# Average Score_3: 56.95000000000001

# %% [markdown]
# ### 8. From the original data frame, calculate the maximum Score_4 value.

# %%
# Find the maximum value of the Score_4 column
score_4_max = df["Score_4"].max()

# Print the result
print("Maximum Score_4:", score_4_max)
# Out:
# Maximum Score_4: 88.8

# %% [markdown]
# ### 9. From the original data frame, calculate the median Score 2 value.

# %%
# Calculate the median of the Score_2 column
score_2_median = df["Score_2"].median()

# Print the result
print("Median Score_2:", score_2_median)
# Out:
# Median Score_2: 40.75

# %% [markdown]
# ### 10. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
# Create the DataFrame
df_orders = pd.DataFrame(orders)

# Print the resulting DataFrame
print(df_orders)
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 11. Calculate the total quantity ordered and revenue generated from these orders.

# %%
# Calculate totals by summing the respective columns
total_quantity = df_orders['Quantity'].sum()
total_revenue = df_orders['Revenue'].sum()

# Print the final results
print(f"Total Quantity Ordered: {total_quantity:,} units")
print(f"Total Revenue Generated: ${total_revenue:,.2f}")
# Out:
# Total Quantity Ordered: 2,978 units
# Total Revenue Generated: $637.00

# %% [markdown]
# ### 12. Obtain the prices of the most expensive and least expensive items ordered and print the difference.

# %%
# Find the maximum and minimum unit prices
max_price = df_orders['UnitPrice'].max()
min_price = df_orders['UnitPrice'].min()

# Calculate the difference
price_difference = max_price - min_price

# Print the results
print(f"Most Expensive Item Price:  ${max_price:.2f}")
print(f"Least Expensive Item Price: ${min_price:.2f}")
print(f"Price Difference:           ${price_difference:.2f}")
# Out:
# Most Expensive Item Price:  $11.95
# Least Expensive Item Price: $0.18
# Price Difference:           $11.77

# %% [markdown]
# ## Let's load another dataset for more exercisesº

# %%
# Run this code:
admissions = pd.read_csv('../Admission_Predict.csv')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
print(admissions)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# ### 1 - Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Check the total number of missing values per column
missing_data_summary = admissions.isnull().sum()

# Print the summary breakdown
print("Missing values per column:")
print(missing_data_summary)

# Proactively confirm if the entire dataset is 100% clean
print("\nIs there any missing data in the entire dataset?", admissions.isnull().values.any())
# Out:
# Missing values per column:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64
#
# Is there any missing data in the entire dataset? False

# %% [markdown]
# ###  2 -  Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Set 'Serial No.' as the index and retain the original column using drop=False
admissions = admissions.set_index('Serial No.', drop=False)

# Verify the change by looking at the first few rows
print(admissions.head())
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# Serial No.
# 1                    1        337          118                  4  4.5   4.5
# 2                    2        316          104                  3  3.0   3.5
# 3                    3        322          110                  3  3.5   2.5
# 4                    4        314          103                  2  2.0   3.0
# 5                    5        330          115                  5  4.5   3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1              0.92
# 2           8.00         1              0.72
# 3           8.67         1              0.80
# 4           8.21         0              0.65
# 5           9.34         1              0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %% [markdown]
# ### 3 - In this part of the lab, we would like to test complex conditions on the entire data set at once. Let's start by finding the number of rows where the CGPA is greater than 9 and the student has performed an investigation.

# %%
# Apply both conditions using the bitwise AND operator (&)
filtered_admissions = admissions[(admissions['CGPA'] > 9) & (admissions['Research'] == 1)]

# Get the count of rows that match
matching_rows_count = len(filtered_admissions)

# Print the result
print(f"Number of rows matching both conditions: {matching_rows_count}")
# Out:
# Number of rows matching both conditions: 101

# %% [markdown]
# ### 4 - Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# 1. Filter rows where CGPA > 9 and SOP < 3.5
# (Note: we use 'Chance of Admit' assuming you stripped the trailing spaces earlier)
complex_filter = admissions[(admissions['CGPA'] > 9) & (admissions['SOP'] < 3.5)]

# 2. Display all the matching rows
print(complex_filter)

# 3. Calculate and print the mean chance of admit
mean_chance = complex_filter['Chance of Admit '].mean()
print(f"Mean Chance of Admit for these applicants: {mean_chance:.4f}")
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# Serial No.
# 29                  29        338          118                  4  3.0   4.5
# 63                  63        327          114                  3  3.0   3.0
# 141                141        326          114                  3  3.0   3.0
# 218                218        324          111                  4  3.0   3.0
# 382                382        325          107                  3  3.0   3.5
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 29          9.40         1              0.91
# 63          9.02         0              0.61
# 141         9.11         1              0.83
# 218         9.01         1              0.82
# 382         9.11         1              0.84
# Mean Chance of Admit for these applicants: 0.8020
